# %%
from BeatRoot import beatTracker

# %%
fileName = '../data/Albums-Ballroom_Classics4-14.wav'
beats = beatTracker(fileName)
print('beats:\n', beats)
# Out:
# the song is 31 seconds
# Tempo Induction: Onset Detection starts...
# Tempo Induction: get onsets successfully
# Tempo Induction: Clustering starts...
# Tempo Induction: generate clusters...it may cost time, please wait...
# get 10 best ranked clusters:
# Interval, Size, Score
# 5.1818 85 905
# 2.0249 86 859
# 4.0368 53 855
# 10.0095 56 729
# 6.0781 37 727
# 0.7418 104 700
# 1.0104 68 680
# 2.0868 74 654
# 7.5675 61 650
# 1.2398 56 641
#
# Agent Initialisation...
# Agent Mainloop...
# get 5 best ranked agents
# remove duplicate agents...
# Beat Interval, History Length, Score
# 0.216 118 31.36
# 0.216 118 30.8704
# 0.216 118 30.7589
# 0.216 117 30.3403
# 0.216 117 30.339
# beats:
#  [0.4, 0.78, 1.45, 1.94, 2.48, 2.98, 3.29, 3.71, 4.03, 4.51, 4.8, 5.03, 5.26, 5.5600000000000005, 5.83, 6.04, 6.28, 6.5600000000000005, 6.78, 7.12, 7.29, 7.59, 7.73, 7.8500000000000005, 8.08, 8.28, 8.46, 8.63, 8.9, 9.03, 9.3, 9.700000000000001, 9.88, 10.05, 10.24, 10.44, 10.74, 11.05, 11.3, 11.44, 11.56, 11.75, 11.9, 12.13, 12.26, 12.49, 12.77, 13.030000000000001, 13.46, 13.83, 14.030000000000001, 14.22, 14.450000000000001, 14.68, 14.86, 15.16, 15.290000000000001, 15.540000000000001, 15.860000000000001, 16.04, 16.240000000000002, 16.55, 16.91, 17.21, 17.38, 17.580000000000002, 17.75, 17.92, 18.06, 18.2, 18.45, 18.67, 18.97, 19.330000000000002, 19.7, 20.05, 20.23, 20.38, 20.53, 20.830000000000002, 21.06, 21.23, 21.55, 21.82, 22.150000000000002, 22.35, 22.6, 22.84, 23.1, 23.45, 23.6, 23.8, 24.150000000000002, 24.46, 24.68, 24.87, 25.150000000000002, 25.41, 25.55, 25.87, 26.02, 26.16, 26.38, 26.64, 26.91, 27.080000000000002, 27.25, 27.38, 27.490000000000002, 27.63, 27.86, 27.98, 28.330000000000002, 28.52, 28.75, 28.97, 29.28, 29.47]
