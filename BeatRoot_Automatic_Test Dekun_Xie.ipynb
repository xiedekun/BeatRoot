# %%
from BeatRoot import beatTracker

# %%
fileName = 'data/Albums-Ballroom_Classics4-14.wav'
beats = beatTracker(fileName)
print('beats:\n', beats)
# Out:
# the song is 31 seconds
# Tempo Induction: Onset Detection starts...
# Tempo Induction: get onsets successfully
# Tempo Induction: Clustering starts...
# Tempo Induction: generate clusters...it may cost time, please wait...
# get 10 best ranked clusters:
# Interval, Size, Score
# 1.7003 37 447
# 1.0104 42 446
# 3.0308 24 446
# 2.0249 33 438
# 3.7156 25 432
# 5.1818 34 431
# 6.8192 24 427
# 1.2398 31 424
# 6.0781 21 422
# 4.0368 28 421
#
# Agent Initialisation...
# Agent Mainloop...
# get 5 best ranked agents
# remove duplicate agents...
# Beat Interval, History Length, Score
# 1.0017 26 14.9421
# 1.0259 27 13.3696
# 1.0017 23 12.799
# 1.0009 25 11.7727
# 1.0006 23 11.315
# Evaluate Precision...
#
# Agent0
# Precision 95.45%
# F-measure 0.4421
#
# Agent1
# Precision 100.0%
# F-measure 0.4948
#
# Agent2
# Precision 95.45%
# F-measure 0.4421
#
# Agent3
# Precision 86.36%
# F-measure 0.4
#
# Agent4
# Precision 86.36%
# F-measure 0.4
#
# Agent1 is the best!
#
# adding cowbell...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# beats:
#  [2.23, 3.29, 4.51, 5.5600000000000005, 6.5600000000000005, 7.59, 8.63, 9.700000000000001, 10.74, 11.75, 12.77, 13.83, 14.86, 15.860000000000001, 16.91, 17.92, 18.97, 20.05, 21.06, 22.150000000000002, 23.1, 24.150000000000002, 25.150000000000002, 26.16, 27.25, 28.330000000000002, 29.28]
